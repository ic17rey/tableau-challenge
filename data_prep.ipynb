# %%
import os

import pandas as pd

# %%
# Identify a variable for the path needed to retrieve the data
mar2019_path = os.path.join('Data', 'Monthly', 'JC-201903-citibike-tripdata.csv')

# Read csv file and store into Pandas DataFrame
mar2019_df = pd.read_csv(mar2019_path)

# View the values in first 5 rows of data frame
mar2019_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               306  2019-03-01 06:47:08.2110  2019-03-01 06:52:14.7150
# 1               123  2019-03-01 07:30:53.0220  2019-03-01 07:32:56.7770
# 2               328  2019-03-01 08:18:30.4030  2019-03-01 08:23:59.0590
# 3                95  2019-03-01 11:04:47.2020  2019-03-01 11:06:22.8130
# 4               169  2019-03-01 11:51:29.4170  2019-03-01 11:54:19.2120
# ...             ...                       ...                       ...
# 23601           916  2019-03-29 13:38:36.1750  2019-03-29 13:53:53.0100
# 23602           661  2019-03-29 15:29:18.7510  2019-03-29 15:40:20.2510
# 23603           577  2019-03-30 13:43:09.2090  2019-03-30 13:52:46.7140
# 23604           585  2019-03-31 08:33:21.5200  2019-03-31 08:43:06.7520
# 23605           914  2019-03-31 14:59:32.3980  2019-03-31 15:14:46.8480
#
#        start station id start station name  start station latitude  \
# ...

# %%
apr2019_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1               493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2               512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3               196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4               463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
# ...             ...                       ...                       ...
# 33051           335  2019-04-27 20:12:13.3830  2019-04-27 20:17:48.5690
# 33052           679  2019-04-28 13:23:04.7290  2019-04-28 13:34:23.7550
# 33053           793  2019-04-29 13:46:39.2540  2019-04-29 13:59:52.2890
# 33054           706  2019-04-30 10:47:41.6730  2019-04-30 10:59:28.5910
# 33055           721  2019-04-30 19:30:56.2830  2019-04-30 19:42:57.6050
#
#        start station id start station name  start station latitude  \
# ...

# %%
mar2019_df.describe()
# Out:
#         tripduration  start station id  start station latitude  \
# count   23606.000000      23606.000000            23606.000000
# mean      546.176353       3273.025756               40.722679
# std      3288.178650        145.557364                0.006955
# min        61.000000       3183.000000               40.709651
# 25%       213.000000       3192.000000               40.718355
# 50%       307.000000       3207.000000               40.721525
# 75%       487.000000       3273.000000               40.727224
# max    260817.000000       3694.000000               40.748716
#
#        start station longitude  end station id  end station latitude  \
# count             23606.000000    23606.000000          23606.000000
# mean                -74.046551     3268.292934             40.722266
# std                   0.010534      150.409518              0.006806
# min                 -74.083639      327.000000             40.709651
# ...

# %%
# Identify variables for the paths needed to retrieve the data
apr2019_path = os.path.join('Data', 'Monthly', 'JC-201904-citibike-tripdata.csv')
may2019_path = os.path.join('Data', 'Monthly', 'JC-201905-citibike-tripdata.csv')
jun2019_path = os.path.join('Data', 'Monthly', 'JC-201906-citibike-tripdata.csv')
jul2019_path = os.path.join('Data', 'Monthly', 'JC-201907-citibike-tripdata.csv')
aug2019_path = os.path.join('Data', 'Monthly', 'JC-201908-citibike-tripdata.csv')

mar2020_path = os.path.join('Data', 'Monthly', 'JC-202003-citibike-tripdata.csv')
apr2020_path = os.path.join('Data', 'Monthly', 'JC-202004-citibike-tripdata.csv')
may2020_path = os.path.join('Data', 'Monthly', 'JC-202005-citibike-tripdata.csv')
jun2020_path = os.path.join('Data', 'Monthly', 'JC-202006-citibike-tripdata.csv')
jul2020_path = os.path.join('Data', 'Monthly', 'JC-202007-citibike-tripdata.csv')
aug2020_path = os.path.join('Data', 'Monthly', 'JC-202008-citibike-tripdata.csv')

mar2021_path = os.path.join('Data', 'Monthly', 'JC-202103-citibike-tripdata.csv')
apr2021_path = os.path.join('Data', 'Monthly', 'JC-202104-citibike-tripdata.csv')
may2021_path = os.path.join('Data', 'Monthly', 'JC-202105-citibike-tripdata.csv')

# Read csv files and store into Pandas DataFrame
apr2019_df = pd.read_csv(apr2019_path)
may2019_df = pd.read_csv(may2019_path)
jun2019_df = pd.read_csv(jun2019_path)
jul2019_df = pd.read_csv(jul2019_path)
aug2019_df = pd.read_csv(aug2019_path)

mar2020_df = pd.read_csv(mar2020_path)
apr2020_df = pd.read_csv(apr2020_path)
may2020_df = pd.read_csv(may2020_path)
jun2020_df = pd.read_csv(jun2020_path)
jul2020_df = pd.read_csv(jul2020_path)
aug2020_df = pd.read_csv(aug2020_path)

mar2021_df = pd.read_csv(mar2021_path)
apr2021_df = pd.read_csv(apr2021_path)
may2021_df = pd.read_csv(may2021_path)

# %%
# View another df
aug2020_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               561  2020-08-01 00:00:16.5960  2020-08-01 00:09:38.5610
# 1               236  2020-08-01 00:00:46.3900  2020-08-01 00:04:42.8890
# 2               384  2020-08-01 00:02:38.9250  2020-08-01 00:09:03.7590
# 3              1302  2020-08-01 00:03:27.0270  2020-08-01 00:25:09.2120
# 4              5561  2020-08-01 00:03:57.4810  2020-08-01 01:36:38.5000
# ...             ...                       ...                       ...
# 43262           162  2020-08-31 23:43:15.8540  2020-08-31 23:45:58.4550
# 43263           400  2020-08-31 23:46:19.9130  2020-08-31 23:53:00.3610
# 43264           288  2020-08-31 23:47:16.8680  2020-08-31 23:52:05.5550
# 43265           199  2020-08-31 23:50:37.2650  2020-08-31 23:53:56.9490
# 43266           333  2020-08-31 23:55:30.8050  2020-09-01 00:01:04.4110
#
#        start station id start station name  start station latitude  \
# ...

# %%
combined2019sprsummer_df = pd.concat((mar2019_df, apr2019_df, may2019_df, jun2019_df, jul2019_df, aug2019_df), axis=0)
combined2019sprsummer_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               306  2019-03-01 06:47:08.2110  2019-03-01 06:52:14.7150
# 1               123  2019-03-01 07:30:53.0220  2019-03-01 07:32:56.7770
# 2               328  2019-03-01 08:18:30.4030  2019-03-01 08:23:59.0590
# 3                95  2019-03-01 11:04:47.2020  2019-03-01 11:06:22.8130
# 4               169  2019-03-01 11:51:29.4170  2019-03-01 11:54:19.2120
# ...             ...                       ...                       ...
# 48706           384  2019-08-31 23:40:45.2450  2019-08-31 23:47:09.8810
# 48707           633  2019-08-31 23:45:55.6660  2019-08-31 23:56:29.5350
# 48708           324  2019-08-31 23:50:27.9220  2019-08-31 23:55:52.8420
# 48709           126  2019-08-31 23:52:21.9250  2019-08-31 23:54:28.5820
# 48710           690  2019-08-31 23:56:55.1530  2019-09-01 00:08:25.2370
#
#        start station id start station name  start station latitude  \
# ...

# %%
combined2020sprsummer_df = pd.concat((mar2020_df, apr2020_df, may2020_df, jun2020_df, jul2020_df, aug2020_df), axis=0)
combined2020sprsummer_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               389  2020-03-01 00:14:07.0000  2020-03-01 00:20:36.0880
# 1               242  2020-03-01 00:48:06.4390  2020-03-01 00:52:08.9870
# 2               124  2020-03-01 01:08:46.4880  2020-03-01 01:10:51.2780
# 3               104  2020-03-01 01:22:35.4790  2020-03-01 01:24:20.2470
# 4               228  2020-03-01 01:39:20.2680  2020-03-01 01:43:09.1380
# ...             ...                       ...                       ...
# 43262           162  2020-08-31 23:43:15.8540  2020-08-31 23:45:58.4550
# 43263           400  2020-08-31 23:46:19.9130  2020-08-31 23:53:00.3610
# 43264           288  2020-08-31 23:47:16.8680  2020-08-31 23:52:05.5550
# 43265           199  2020-08-31 23:50:37.2650  2020-08-31 23:53:56.9490
# 43266           333  2020-08-31 23:55:30.8050  2020-09-01 00:01:04.4110
#
#        start station id start station name  start station latitude  \
# ...

# %%
combined2021spr_df = pd.concat((mar2021_df, apr2021_df, may2021_df), axis=0)
combined2021spr_df
# Out:
#                 ride_id rideable_type           started_at  \
# 0      ABBBB4D89C620898   docked_bike  2021-03-03 10:32:07
# 1      987BC8C414C77F3E   docked_bike  2021-03-14 00:21:37
# 2      342C5C515F0F8BCB   docked_bike  2021-03-21 14:39:46
# 3      AB28945141163E31   docked_bike  2021-03-14 00:27:21
# 4      4F5758803BC3DE72   docked_bike  2021-03-12 20:45:29
# ...                 ...           ...                  ...
# 45038  62FF3FEDAAD7FCB3   docked_bike  2021-05-31 12:46:22
# 45039  E742AEA7068E0E4A   docked_bike  2021-05-31 16:34:19
# 45040  E769F9EE96D6433A   docked_bike  2021-05-17 22:52:35
# 45041  EC973614DCA179A2   docked_bike  2021-05-31 20:48:58
# 45042  3571180FE5C52CB1   docked_bike  2021-05-23 14:28:43
#
#                   ended_at start_station_name start_station_id  \
# 0      2021-03-03 10:32:40     Jackson Square            JC063
# 1      2021-03-14 00:22:59     Jackson Square            JC063
# 2      2021-03-21 15:33:10     Jackson Square            JC063
# ...

# %%
# Export file as CSV, without the Pandas index, but with the header
sprsummer2019_path = os.path.join('Data', 'Seasonal', 'sprsummer2019-citibike-tripdata.csv')
combined2019sprsummer_df.to_csv(sprsummer2019_path, index=False, header=True)

# %%
# Export file as CSV, without the Pandas index, but with the header
sprsummer2020_path = os.path.join('Data', 'Seasonal', 'sprsummer2020-citibike-tripdata.csv')
combined2020sprsummer_df.to_csv(sprsummer2020_path, index=False, header=True)

# %%
# Export file as CSV, without the Pandas index, but with the header
spr2021_path = os.path.join('Data', 'Seasonal', 'spr2021-citibike-tripdata.csv')
combined2021spr_df.to_csv(spr2021_path, index=False, header=True)
